# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pathlib import Path

# %%
df=pd.read_csv("../data/train.csv")

# %%
df.head(1)
# Out:
#           id                                              title  \
# 0  303438042  World's Cellar Cathedral Cove Merlot Cabernet ...
#
#                                                  img         size    price  \
# 0  //sg-live-01.slatic.net/p/09fb0dbc88054dcfa4bd...  6 Ã— 750 ml  118.00$
#
#    reviews  rating
# 0     16.0   4.875

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# RedMart Medium Duty Clear Knife 6                                5.0
# RedMart Australian Cauliflower 950g (plastic free packaging))    5.0
# RedMart Wooden Fork (30 PCS)                                     5.0
# RedMart Antibacterial Wet Wipes - Case                           5.0
# RedMart Wooden Spoon (30 PCS)                                    5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# World's Cellar Pampre-Matin Chardonnay                                       6
# World's Cellar Chateau Croix du Bailli Montagne Saint-Emilion Red Wine       5
# RedMart Crumbed Cage-Free Whole Fried Chicken Tenderloin Nuggets - Frozen    5
# RedMart Chocolate Tea Cake                                                   5
# RedMart Cage Free Australian Chicken Drumsticks - Frozen                     5
# Name: rating, dtype: int64

# %%
ratings_mean_count = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings_mean_count
# Out:
#                                             rating
# title
# AW'S Market Chilled Striploin             4.222222
# AW'S Market Indonesian Pork Fillet        4.869565
# AW'S Market USDA Angus Ribeye             4.529412
# Adams 100% Natural Creamy Peanut Butter   4.647727
# Adams 100% Natural Crunchy Peanut Butter  4.743827
# ...                                            ...
# YUVVO Red Onions                          4.765048
# Yakult Original Cultured Milk - SG        4.878472
# Yotsuba Hokkaido Fresh Milk 1L            4.882779
# Zespri Gold Kiwi 5s                       4.788104
# Zespri SunGold 3s Golden Kiwi             4.744802
#
# [522 rows x 1 columns]

# %%
ratings_mean_count['rating_counts'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings_mean_count
# Out:
#                                             rating  rating_counts
# title
# AW'S Market Chilled Striploin             4.222222              1
# AW'S Market Indonesian Pork Fillet        4.869565              1
# AW'S Market USDA Angus Ribeye             4.529412              1
# Adams 100% Natural Creamy Peanut Butter   4.647727              1
# Adams 100% Natural Crunchy Peanut Butter  4.743827              1
# ...                                            ...            ...
# YUVVO Red Onions                          4.765048              1
# Yakult Original Cultured Milk - SG        4.878472              1
# Yotsuba Hokkaido Fresh Milk 1L            4.882779              1
# Zespri Gold Kiwi 5s                       4.788104              1
# Zespri SunGold 3s Golden Kiwi             4.744802              1
#
# [522 rows x 2 columns]

# %%
sns.set_style('dark')
# %matplotlib inline

plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['rating_counts'].hist(bins=50)

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['rating'].hist(bins=50)

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
sns.jointplot(x='rating', y='rating_counts', data=ratings_mean_count, alpha=0.4)

# %%
id_rating =df.pivot_table(index='id', columns='title', values='rating')

# %%
id_rating.head()
# Out:
# title      AW'S Market Chilled Striploin  AW'S Market Indonesian Pork Fillet  \
# id
# 301076866                            NaN                                 NaN
# 301076940                            NaN                                 NaN
# 301076948                            NaN                                 NaN
# 301076954                            NaN                                 NaN
# 301076962                            NaN                                 NaN
#
# title      AW'S Market USDA Angus Ribeye  \
# id
# 301076866                            NaN
# 301076940                            NaN
# 301076948                            NaN
# 301076954                            NaN
# 301076962                            NaN
#
# title      Adams 100% Natural Creamy Peanut Butter  \
# id
# 301076866                                      NaN
# 301076940                                      NaN
# 301076948                                      NaN
# ...

# %%
product_ratings = id_rating["RedMart 20 Gallon Medium Zipper Bags (ziplock bags)"]

# %%
product_ratings
# Out:
# id
# 301076866   NaN
# 301076940   NaN
# 301076948   NaN
# 301076954   NaN
# 301076962   NaN
#              ..
# 696880946   NaN
# 696926485   NaN
# 721442990   NaN
# 721458741   NaN
# 782106821   NaN
# Name: RedMart 20 Gallon Medium Zipper Bags (ziplock bags), Length: 525, dtype: float64

# %%
product_like = id_rating.corrwith(product_ratings)

corr_product = pd.DataFrame(product_like, columns=['Correlation'])
corr_product.dropna(inplace=True)
